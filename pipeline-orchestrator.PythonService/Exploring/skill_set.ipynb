# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
sys.path.insert(0, str(PROJECT_ROOT))

# %%
import pandas as pd

df = pd.read_csv("../Data/set/digitalSkillsCollection_en.csv")
print(df.columns.tolist())
print(df["broaderConceptPT"][162])
print(df["preferredLabel"][162])
print(df["description"][162])
print(df["conceptType"][162])
# Out:
# ['conceptType', 'conceptUri', 'preferredLabel', 'status', 'skillType', 'reuseLevel', 'altLabels', 'description', 'broaderConceptUri', 'broaderConceptPT']
# software and applications development and analysis
# Angular
