# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
sys.path.insert(0, str(PROJECT_ROOT))

# %%
import pandas as pd

df = pd.read_csv("../Data/set/digitalSkillsCollection_en.csv")
print(len(df.columns.tolist()))
print(df["preferredLabel"][162])
print(df["altLabels"][162])
print(df["broaderConceptPT"][162])
# Out:
# 10
# Angular
# Angular related algorithms | testing in Angular | programming paradigms in Angular | coding in Angular | Angular techniques and principles
# software and applications development and analysis
